# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\varsh\Downloads\Adidas US Sales Datasets 1.csv")
df
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker    1185732.0   01-01-2020  Northeast       New York
# 1     Foot Locker    1185732.0   02-01-2020  Northeast       New York
# 2     Foot Locker    1185732.0   03-01-2020  Northeast       New York
# 3     Foot Locker    1185732.0   04-01-2020  Northeast       New York
# 4     Foot Locker    1185732.0   05-01-2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker    1185732.0   24-01-2021  Northeast  New Hampshire
# 9644  Foot Locker    1185732.0   24-01-2021  Northeast  New Hampshire
# 9645  Foot Locker    1185732.0   22-02-2021  Northeast  New Hampshire
# 9646  Foot Locker    1185732.0   22-02-2021  Northeast  New Hampshire
# 9647  Foot Locker    1185732.0   22-02-2021  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   float64
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   float64
#  8   Units Sold        9648 non-null   float64
#  9   Total Sales       9648 non-null   float64
#  10  Operating Profit  9648 non-null   float64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
# dtypes: float64(6), object(7)
# memory usage: 980.0+ KB
#         Retailer ID  Price per Unit   Units Sold    Total Sales  \
# ...

# %%
sales_by_city = df.groupby("City")["Total Sales"].sum().reset_index()
sales_by_city = sales_by_city.sort_values(by="Total Sales", ascending=False)
print(sales_by_city.head(10))
# Out:
#              City  Total Sales
# 10     Charleston   39974797.0
# 35       New York   39801235.0
# 46  San Francisco   34539220.0
# 31          Miami   31600863.0
# 42       Portland   30545652.0
# 39        Orlando   27682851.0
# 47        Seattle   26330718.0
# 28    Los Angeles   25634913.0
# 22        Houston   25456882.0
# 0          Albany   24427804.0

# %%
sales_by_state = df.groupby("State")["Total Sales"].sum().reset_index()
sales_by_state = sales_by_state.sort_values(by="Total Sales", ascending=False)
print(sales_by_state.head(10))
# Out:
#              State  Total Sales
# 31        New York   64229039.0
# 4       California   60174133.0
# 8          Florida   59283714.0
# 42           Texas   46359746.0
# 39  South Carolina   29285637.0
# 46      Washington   26330718.0
# 32  North Carolina   23956531.0
# 17       Louisiana   23750781.0
# 10          Hawaii   22282457.0
# 45        Virginia   21575040.0

# %%
sales_by_region = df.groupby("Region")["Total Sales"].sum().reset_index()
sales_by_region = sales_by_region.sort_values(by="Total Sales", ascending=False)
print(sales_by_region)
# Out:
#       Region  Total Sales
# 4       West  269943182.0
# 1  Northeast  186324067.0
# 3  Southeast  163171236.0
# 2      South  144663181.0
# 0    Midwest  135800459.0

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=sales_by_city["City"][:10], y=sales_by_city["Total Sales"][:10], palette="Blues_r")
plt.xticks(rotation=45)
plt.title("Top 10 Cities by Sales")
plt.xlabel("City")
plt.ylabel("Total Sales")
plt.show()
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_48280\2702145078.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sales_by_city["City"][:10], y=sales_by_city["Total Sales"][:10], palette="Blues_r")

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=sales_by_region["Region"], y=sales_by_region["Total Sales"], palette="coolwarm")
plt.title("Sales Performance by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_48280\1150309909.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sales_by_region["Region"], y=sales_by_region["Total Sales"], palette="coolwarm")

# %%
best_city = sales_by_city.iloc[0]  
worst_city = sales_by_city.iloc[-1]
print(f"Best Performing City: {best_city['City']} - Sales: ${best_city['Total Sales']}")
print(f"Worst Performing City: {worst_city['City']} - Sales: ${worst_city['Total Sales']}")
# Out:
# Best Performing City: Charleston - Sales: $39974797.0
# Worst Performing City: Omaha - Sales: $5929038.0

# %%
sales_by_retailer = df.groupby("Retailer")["Total Sales"].sum().reset_index()
sales_by_retailer = sales_by_retailer.sort_values(by="Total Sales", ascending=False)
sales_by_retailer.head(3)
# Out:
#         Retailer  Total Sales
# 5      West Gear  242964333.0
# 1    Foot Locker  220094720.0
# 3  Sports Direct  182470997.0

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x=df["Price per Unit"], y=df["Total Sales"])
plt.title("Price per Unit vs Total Sales")
plt.xlabel("Price per Unit")
plt.ylabel("Total Sales")
plt.show()

# %%
sales_by_product = df.groupby("Product")["Total Sales"].sum().reset_index()
sales_by_product = sales_by_product.sort_values(by="Total Sales", ascending=False)
sales_by_product.head(3)
# Out:
#                      Product  Total Sales
# 2      Men's Street Footwear  208826244.0
# 3            Women's Apparel  179038860.0
# 1    Men's Athletic Footwear  153673680.0
# 5    Women's Street Footwear  128002813.0
# 0              Men's Apparel  123728632.0
# 4  Women's Athletic Footwear  106631896.0

# %%
plt.figure(figsize=(6,6))
sns.barplot(x=sales_by_product["Product"][:10], y=sales_by_product["Total Sales"][:10], palette="coolwarm")
plt.xticks(rotation=45)
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.show()
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_48280\2591855324.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sales_by_product["Product"][:10], y=sales_by_product["Total Sales"][:10], palette="coolwarm")

# %%
sales_by_method = df.groupby("Sales Method")["Total Sales"].sum().reset_index()
sales_by_method = sales_by_method.sort_values(by="Total Sales", ascending=False)
sales_by_method
# Out:
#   Sales Method  Total Sales
# 0     In-store  356643750.0
# 2       Outlet  295585493.0
# 1       Online  247672882.0

# %%
plt.figure(figsize=(6,6))
sns.barplot(x=sales_by_method["Sales Method"], y=sales_by_method["Total Sales"], palette="coolwarm")
plt.xticks(rotation=45)
plt.xlabel("Sales Method")
plt.ylabel("Total Sales")
plt.show()
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_48280\3522709802.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sales_by_method["Sales Method"], y=sales_by_method["Total Sales"], palette="coolwarm")

# %%
popular_products = df.groupby("Product")["Units Sold"].sum().reset_index()
popular_products = popular_products.sort_values(by="Units Sold", ascending=False)
popular_products
# Out:
#                      Product  Units Sold
# 2      Men's Street Footwear    593320.0
# 1    Men's Athletic Footwear    435526.0
# 3            Women's Apparel    433827.0
# 5    Women's Street Footwear    392269.0
# 4  Women's Athletic Footwear    317236.0
# 0              Men's Apparel    306683.0

# %%
popular_products.plot(kind = 'bar')
sns.barplot(x=popular_products["Product"], y=popular_products["Units Sold"], palette="coolwarm")
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_48280\3385134457.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=popular_products["Product"], y=popular_products["Units Sold"], palette="coolwarm")
# <Axes: xlabel='Product', ylabel='Units Sold'>

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df["Price per Unit"], y=df["Units Sold"])
plt.title("Price per Unit vs Units Sold")
plt.xlabel("Price per Unit")
plt.ylabel("Units Sold")
plt.show()

# %%
df["Invoice Date"] = pd.to_datetime(df["Invoice Date"], format="%d-%m-%Y") 
df["Month"] = df["Invoice Date"].dt.month  # Extract month  

sales_by_month = df.groupby("Month")["Units Sold"].sum().reset_index()

plt.figure(figsize=(6,6))
sns.lineplot(x=sales_by_month["Month"], y=sales_by_month["Units Sold"], marker="o", color="b")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Units Sold")
plt.xticks(range(1,13), ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])
plt.show()

# %%
sales_by_region = df.groupby("Region")["Units Sold"].sum().reset_index()
sales_by_region = sales_by_region.sort_values(by="Units Sold", ascending=False)
sales_by_region
# Out:
#       Region  Units Sold
# 4       West    686985.0
# 1  Northeast    501279.0
# 2      South    492260.0
# 3  Southeast    407000.0
# 0    Midwest    391337.0

# %%
sns.lineplot(x=sales_by_region["Region"], y=sales_by_region["Units Sold"], marker="o", color="b")
# Out:
# <Axes: xlabel='Region', ylabel='Units Sold'>
